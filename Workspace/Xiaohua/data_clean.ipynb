# %%
import pandas as pd

from surprise import Dataset, Reader, accuracy
from surprise.model_selection import cross_validate,GridSearchCV, train_test_split
from surprise.prediction_algorithms import SVD, SVDpp, NMF, BaselineOnly, NormalPredictor

# %%
movie_rating = pd.read_csv('./movie_rating.csv')


reader = Reader(rating_scale=(1, 5))
complete_data = Dataset.load_from_df(movie_rating[['userId', 'movieId', 'rating']], reader)


#use surprises
train, test = train_test_split(complete_data, random_state=42)

#best model
final_model = SVD(n_factors=125,n_epochs=45,lr_all=0.015,reg_all=0.1)

#get the full training dataset
#so this is the full train data in surprise dataset
full_data = complete_data.build_full_trainset()
#fit the full_data which is a surprise dataset
final_model.fit(full_data)

# %%
movie_rating = pd.read_csv('./movie_rating.csv')

#for the function/final mode
reader = Reader(rating_scale=(1, 5))
complete_data = Dataset.load_from_df(movie_rating[['userId', 'movieId', 'rating']], reader)


#use sklearn
#for model selection/choosing? 
train, test = train_test_split(movie_rating, random_state=42)

reader = Reader(rating_scale=(1, 5))
train_data = Dataset.load_from_df(train[['userId', 'movieId', 'rating']], reader)
test_data = Dataset.load_from_df(test[['userId', 'movieId', 'rating']], reader)

train_data2 = train_data.build_full_trainset()
test_data2 = test_data.build_full_trainset().build_testset()


# #best model
final_model = SVD(n_factors=125,n_epochs=45,lr_all=0.015,reg_all=0.1)

# #get the full training dataset
# #so this is the full train data in surprise dataset
full_data = complete_data.build_full_trainset()
# #fit the full_data which is a surprise dataset
final_model.fit(full_data)

# %%
cross_validate(SVD(n_factors=125,n_epochs=45,lr_all=0.015,reg_all=0.1), train_data, cv =2)
# Out:
# {'test_rmse': array([0.88037976, 0.88222421]),
#  'test_mae': array([0.67545966, 0.67979407]),
#  'fit_time': (5.51861834526062, 5.390131235122681),
#  'test_time': (0.2620210647583008, 0.5880486965179443)}

# %%
model = SVD(n_factors=125,n_epochs=45,lr_all=0.015,reg_all=0.1).fit(train_data2)

# %%
model_stuff = model.test(test_data2)

# %%
accuracy.rmse(model_stuff)
# Out:
# RMSE: 0.8601
# 0.8601198184521676

# %%
movies = pd.read_csv('../../ml-latest-small/movies.csv')

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 3 columns]

# %%
movie_rating.head()
# Out:
#    movieId                                       genres       Title  \
# 0        1  adventure,animation,children,comedy,fantasy  Toy Story
# 1        1  adventure,animation,children,comedy,fantasy  Toy Story
# 2        1  adventure,animation,children,comedy,fantasy  Toy Story
# 3        1  adventure,animation,children,comedy,fantasy  Toy Story
# 4        1  adventure,animation,children,comedy,fantasy  Toy Story
#
#   year_released  userId  rating            timestamp
# 0          1995     1.0     4.0  2000-07-30 18:45:03
# 1          1995     5.0     4.0  1996-11-08 06:36:02
# 2          1995     7.0     4.5  2005-01-25 06:52:26
# 3          1995    15.0     2.5  2017-11-13 12:59:30
# 4          1995    17.0     4.5  2011-05-18 05:28:03

# %%
complete_data

# %%
userdf = movie_rating.set_index('userId')

# %%
userdf
# Out:
#         movieId                                       genres  \
# userId
# 1.0           1  adventure,animation,children,comedy,fantasy
# 5.0           1  adventure,animation,children,comedy,fantasy
# 7.0           1  adventure,animation,children,comedy,fantasy
# 15.0          1  adventure,animation,children,comedy,fantasy
# 17.0          1  adventure,animation,children,comedy,fantasy
# ...         ...                                          ...
# 184.0    193581              action,animation,comedy,fantasy
# 184.0    193583                     animation,comedy,fantasy
# 184.0    193585                                        drama
# 184.0    193587                             action,animation
# 331.0    193609                                       comedy
#
#                                       Title year_released  rating  \
# userId
# 1.0                              Toy Story           1995     4.0
# 5.0                              Toy Story           1995     4.0
# 7.0                              Toy Story           1995     4.5
# 15.0                             Toy Story           1995     2.5
# 17.0                             Toy Story           1995     4.5
# ...                                     ...           ...     ...
# 184.0   Black Butler: Book of the Atlantic           2017     4.0
# 184.0                No Game No Life: Zero           2017     3.5
# 184.0                                Flint           2017     3.5
# 184.0         Bungo Stray Dogs: Dead Apple           2018     3.5
# 331.0         Andrew Dice Clay: Dice Rules           1991     4.0
#
#                   timestamp
# userId
# 1.0     2000-07-30 18:45:03
# 5.0     1996-11-08 06:36:02
# 7.0     2005-01-25 06:52:26
# 15.0    2017-11-13 12:59:30
# 17.0    2011-05-18 05:28:03
# ...                     ...
# 184.0   2018-09-16 14:44:42
# 184.0   2018-09-16 14:52:25
# 184.0   2018-09-16 14:56:45
# 184.0   2018-09-16 15:00:21
# 331.0   2018-09-17 04:13:26
#
# [100813 rows x 6 columns]

# %%
userdf1 = userdf['movieId']

# %%
userdf1.loc[9,]
# Out:
# userId
# 9.0      41
# 9.0     187
# 9.0     223
# 9.0     371
# 9.0     627
# 9.0     922
# 9.0     923
# 9.0    1037
# 9.0    1095
# 9.0    1198
# 9.0    1270
# 9.0    1674
# 9.0    1987
# 9.0    2011
# 9.0    2012
# 9.0    2023
# 9.0    2300
# 9.0    2877
# 9.0    2901
# 9.0    3173
# 9.0    3328
# 9.0    3735
# 9.0    4131
# 9.0    4558
# 9.0    4993
# 9.0    5218
# 9.0    5378
# 9.0    5445
# 9.0    5447
# 9.0    5451
# 9.0    5481
# 9.0    5507
# 9.0    5841
# 9.0    5843
# 9.0    5872
# 9.0    5890
# 9.0    5891
# 9.0    5893
# 9.0    5902
# 9.0    5952
# 9.0    5956
# 9.0    5962
# 9.0    5965
# 9.0    5988
# 9.0    6001
# 9.0    6044
# Name: movieId, dtype: int64

# %%
user_rate = list(userdf1.loc[9,])

# %%
user_rate
# Out:
# [41,
#  187,
#  223,
#  371,
#  627,
#  922,
#  923,
#  1037,
#  1095,
#  1198,
#  1270,
#  1674,
#  1987,
#  2011,
#  2012,
#  2023,
#  2300,
#  2877,
#  2901,
#  3173,
#  3328,
#  3735,
#  4131,
#  4558,
#  4993,
#  5218,
#  5378,
#  5445,
#  5447,
#  5451,
#  5481,
#  5507,
#  5841,
#  5843,
#  5872,
#  5890,
#  5891,
#  5893,
#  5902,
#  5952,
#  5956,
#  5962,
#  5965,
#  5988,
#  6001,
#  6044]

# %%
moviedf = movies.set_index('movieId')

# %%
moviedf
# Out:
#                                              title  \
# movieId
# 1                                 Toy Story (1995)
# 2                                   Jumanji (1995)
# 3                          Grumpier Old Men (1995)
# 4                         Waiting to Exhale (1995)
# 5               Father of the Bride Part II (1995)
# ...                                            ...
# 193581   Black Butler: Book of the Atlantic (2017)
# 193583                No Game No Life: Zero (2017)
# 193585                                Flint (2017)
# 193587         Bungo Stray Dogs: Dead Apple (2018)
# 193609         Andrew Dice Clay: Dice Rules (1991)
#
#                                               genres
# movieId
# 1        Adventure|Animation|Children|Comedy|Fantasy
# 2                         Adventure|Children|Fantasy
# 3                                     Comedy|Romance
# 4                               Comedy|Drama|Romance
# 5                                             Comedy
# ...                                              ...
# 193581               Action|Animation|Comedy|Fantasy
# 193583                      Animation|Comedy|Fantasy
# 193585                                         Drama
# 193587                              Action|Animation
# 193609                                        Comedy
#
# [9742 rows x 2 columns]

# %%
moviedf.drop(user_rate, inplace = True)

# %%
moviedf
# Out:
#                                              title  \
# movieId
# 1                                 Toy Story (1995)
# 2                                   Jumanji (1995)
# 3                          Grumpier Old Men (1995)
# 4                         Waiting to Exhale (1995)
# 5               Father of the Bride Part II (1995)
# ...                                            ...
# 193581   Black Butler: Book of the Atlantic (2017)
# 193583                No Game No Life: Zero (2017)
# 193585                                Flint (2017)
# 193587         Bungo Stray Dogs: Dead Apple (2018)
# 193609         Andrew Dice Clay: Dice Rules (1991)
#
#                                               genres
# movieId
# 1        Adventure|Animation|Children|Comedy|Fantasy
# 2                         Adventure|Children|Fantasy
# 3                                     Comedy|Romance
# 4                               Comedy|Drama|Romance
# 5                                             Comedy
# ...                                              ...
# 193581               Action|Animation|Comedy|Fantasy
# 193583                      Animation|Comedy|Fantasy
# 193585                                         Drama
# 193587                              Action|Animation
# 193609                                        Comedy
#
# [9696 rows x 2 columns]

# %%
moviedf = moviedf.reset_index()

# %%
moviedf
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9691   193581  Black Butler: Book of the Atlantic (2017)
# 9692   193583               No Game No Life: Zero (2017)
# 9693   193585                               Flint (2017)
# 9694   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9695   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9691              Action|Animation|Comedy|Fantasy
# 9692                     Animation|Comedy|Fantasy
# 9693                                        Drama
# 9694                             Action|Animation
# 9695                                       Comedy
#
# [9696 rows x 3 columns]

# %%
moviedf['est_rating'] = moviedf['movieId'].apply(lambda x: final_model.predict(9, x).est)
moviedf.sort_values(by='est_rating', ascending=False, inplace=True)

# %%
moviedf
# Out:
#       movieId                                              title  \
# 8793   132333                                        Seve (2014)
# 812      1080                Monty Python's Life of Brian (1979)
# 5575    27156  Neon Genesis Evangelion: The End of Evangelion...
# 4014     5747                                   Gallipoli (1981)
# 2264     3030                                     Yojimbo (1961)
# ...       ...                                                ...
# 1162     1556                     Speed 2: Cruise Control (1997)
# 2942     3973              Book of Shadows: Blair Witch 2 (2000)
# 6791    61348                              Disaster Movie (2008)
# 3778     5323                                     Jason X (2002)
# 6095    43919                                  Date Movie (2006)
#
#                                      genres  est_rating
# 8793                      Documentary|Drama    4.649595
# 812                                  Comedy    4.597431
# 5575  Action|Animation|Drama|Fantasy|Sci-Fi    4.585550
# 4014                              Drama|War    4.583046
# 2264                       Action|Adventure    4.581315
# ...                                     ...         ...
# 1162                Action|Romance|Thriller    1.384163
# 2942          Crime|Horror|Mystery|Thriller    1.368453
# 6791                                 Comedy    1.367101
# 3778                 Horror|Sci-Fi|Thriller    1.258974
# 6095                         Comedy|Romance    1.226476
#
# [9696 rows x 4 columns]

# %%
#creating a variable that only has the userid and movies that they've rated
#this uses the original train dataset not surprise's version
users_movies_seen = full_data[['movieId', 'userId']]
#setting user id as index to make it easier to use loc on it
# users_movies_seen.set_index('userId')

users_movies_seen
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-aab65bbd927e> in <module>
#       1 #creating a variable that only has the userid and movies that they've rated
#       2 #this uses the original train dataset not surprise's version
# ----> 3 users_movies_seen = full_data[['movieId', 'userId']]
#       4 #setting user id as index to make it easier to use loc on it
#       5 # users_movies_seen.set_index('userId')
#
# TypeError: 'Trainset' object is not subscriptable

# %%
#function to get stuff up
def stuff():
    user = float(input('userId: '))
    genre = input('What genres are you interested in? ')
    num_recs = int(input('How many recomendations would you like? '))

    #using the train data?
    #create the seen_movie
    seen_movie = list(users_movies_seen.loc[user, 'movieId'])

    #create df with all the unseen/unrated movies
    train_copy = movies.copy()
    train_copy2 = train_copy.set_index('movieId')
    
    #using the not_seen df, create a rating for a user
    not_seen = train_copy2.drop(index = seen_movie)

    #subsetting the df to unseen movies of a certain genre
    not_seen = not_seen[not_seen['genres'] == genre]
    
    #reset not_seen index
    not_seen = not_seen.reset_index()
    
    #creating an est rating and the sorted it
moviedf['est_rating'] = moviedf['movieId'].apply(lambda x: final_model.predict(9, x).est)
moviedf.sort_values(by='est_rating', ascending=False, inplace=True)

    #returns the recommendations that the model predicts to be the highest rating
    return (not_seen.head(num_recs))

# %%
stuff()
# Out:
# userId: 2.0
# What genres are you interested in? comedy
# How many recomendations would you like? 5
# Empty DataFrame
# Columns: [movieId, title, genres, est_rating]
# Index: []

# %%
users_movies_seen = train[['movieId', 'userId']]

# %%
users_movies_seen.set_index('userId', inplace = True)

# %%
user = float(input('userId: '))
genre = input('What genres are you interested in? ')
num_recs = float(input('How many recomendations would you like? '))
# Out:
# userId: 2.0
# What genres are you interested in? comedy
# How many recomendations would you like? 5

# %%
seen_movie = list(users_movies_seen.loc[user, 'movieId'])

# %%
len(seen_movie)
# Out:
# 26

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 3 columns]

# %%
seen_movie
# Out:
# [80489,
#  91529,
#  91658,
#  112552,
#  58559,
#  333,
#  79132,
#  131724,
#  109487,
#  99114,
#  86345,
#  115713,
#  60756,
#  68157,
#  1704,
#  74458,
#  48516,
#  80906,
#  318,
#  46970,
#  77455,
#  3578,
#  106782,
#  114060,
#  8798,
#  6874]

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 3 columns]

# %%
train_copy = movies.copy()
train_copy2 = train_copy.set_index('movieId')
# not_seen = train_copy.drop()

# %%
train_copy2
# Out:
#                                              title  \
# movieId
# 1                                 Toy Story (1995)
# 2                                   Jumanji (1995)
# 3                          Grumpier Old Men (1995)
# 4                         Waiting to Exhale (1995)
# 5               Father of the Bride Part II (1995)
# ...                                            ...
# 193581   Black Butler: Book of the Atlantic (2017)
# 193583                No Game No Life: Zero (2017)
# 193585                                Flint (2017)
# 193587         Bungo Stray Dogs: Dead Apple (2018)
# 193609         Andrew Dice Clay: Dice Rules (1991)
#
#                                               genres
# movieId
# 1        Adventure|Animation|Children|Comedy|Fantasy
# 2                         Adventure|Children|Fantasy
# 3                                     Comedy|Romance
# 4                               Comedy|Drama|Romance
# 5                                             Comedy
# ...                                              ...
# 193581               Action|Animation|Comedy|Fantasy
# 193583                      Animation|Comedy|Fantasy
# 193585                                         Drama
# 193587                              Action|Animation
# 193609                                        Comedy
#
# [9742 rows x 2 columns]

# %%
len(seen_movie)
# Out:
# 26

# %%
train_copy
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 3 columns]

# %%
train_copy2
# Out:
#                                              title  \
# movieId
# 1                                 Toy Story (1995)
# 2                                   Jumanji (1995)
# 3                          Grumpier Old Men (1995)
# 4                         Waiting to Exhale (1995)
# 5               Father of the Bride Part II (1995)
# ...                                            ...
# 193581   Black Butler: Book of the Atlantic (2017)
# 193583                No Game No Life: Zero (2017)
# 193585                                Flint (2017)
# 193587         Bungo Stray Dogs: Dead Apple (2018)
# 193609         Andrew Dice Clay: Dice Rules (1991)
#
#                                               genres
# movieId
# 1        Adventure|Animation|Children|Comedy|Fantasy
# 2                         Adventure|Children|Fantasy
# 3                                     Comedy|Romance
# 4                               Comedy|Drama|Romance
# 5                                             Comedy
# ...                                              ...
# 193581               Action|Animation|Comedy|Fantasy
# 193583                      Animation|Comedy|Fantasy
# 193585                                         Drama
# 193587                              Action|Animation
# 193609                                        Comedy
#
# [9742 rows x 2 columns]

# %%
train_copy2.reset_index()
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 3 columns]

# %%
dropping = train_copy.drop(index = 'movieId', level = seen_movie)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-34-fce9f2309187> in <module>
# ----> 1 dropping = train_copy.drop(index = 'movieId', level = seen_movie)
#
# ~\anaconda3\envs\tensor\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\envs\tensor\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4952                 weight  1.0     0.8
#    4953         """
# -> 4954         return super().drop(
#    4955             labels=labels,
#    4956             axis=axis,
#
# ~\anaconda3\envs\tensor\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
#    4266             if labels is not None:
# -> 4267                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4268
#    4269         if inplace:
#
# ~\anaconda3\envs\tensor\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4306             if level is not None:
#    4307                 if not isinstance(axis, MultiIndex):
# -> 4308                     raise AssertionError("axis must be a MultiIndex")
#    4309                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4310             else:
#
# AssertionError: axis must be a MultiIndex

# %%
dropping
# Out:
#                                              title  \
# movieId
# 1                                 Toy Story (1995)
# 2                                   Jumanji (1995)
# 3                          Grumpier Old Men (1995)
# 4                         Waiting to Exhale (1995)
# 5               Father of the Bride Part II (1995)
# ...                                            ...
# 193581   Black Butler: Book of the Atlantic (2017)
# 193583                No Game No Life: Zero (2017)
# 193585                                Flint (2017)
# 193587         Bungo Stray Dogs: Dead Apple (2018)
# 193609         Andrew Dice Clay: Dice Rules (1991)
#
#                                               genres
# movieId
# 1        Adventure|Animation|Children|Comedy|Fantasy
# 2                         Adventure|Children|Fantasy
# 3                                     Comedy|Romance
# 4                               Comedy|Drama|Romance
# 5                                             Comedy
# ...                                              ...
# 193581               Action|Animation|Comedy|Fantasy
# 193583                      Animation|Comedy|Fantasy
# 193585                                         Drama
# 193587                              Action|Animation
# 193609                                        Comedy
#
# [9716 rows x 2 columns]

# %%
def stuff():
    user = float(input('userId: '))
    genre = input('What genres are you interested in? ')
    num_recs = int(input('How many recomendations would you like? '))

    #using the train data
    #create the seen_movie
    seen_movie = list(users_movies_seen.loc[user, 'movieId'])

    #create df with all the unseen/unrated movies
    train_copy = movies.copy()
    train_copy2 = train_copy.set_index('movieId')

    #using the not_seen df, create a rating for a user
    not_seen = train_copy2.drop(index = seen_movie)

    #subsetting the df to unseen movies of a certain genre
    not_seen = not_seen[not_seen['genres'].str.contains(genre)]
    
    #reset not_seen index
    not_seen = not_seen.reset_index()
    
    #creating an est rating and the sorted it
    not_seen['est_rating'] = not_seen['movieId'].apply(lambda x: final_model.predict(user, x).est)
    not_seen.sort_values(by='est_rating', ascending=False, inplace=True)

    #returns the recommendations that the model predicts to be the highest rating
    return (not_seen.head(num_recs))

# %%
9742 - 9716
# Out:
# 26

# %%
train_subset = train_copy[train_copy['movieId'] == 80489]

# %%
train_subset
# Out:
#       movieId             title                genres
# 7415    80489  Town, The (2010)  Crime|Drama|Thriller
